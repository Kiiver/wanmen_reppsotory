# %%
#-*- coding:utf-8 -*-

import pandas as pd

def loadCSV(file_name):
    file_a = pd.read_csv(file_name)
    pd.set_option('max_colwidth', 2000)  # 显示句子最长字符长度
#    file = file.drop_duplicates(subset=['sheetID'], keep='first')   # 原有11000+条记录，删除重复sheetID，剩6300+
#    file = file.reset_index(drop=True)  # 重建索引
    return file_a

if __name__ == "__main__":
    file_sorted = loadCSV("new.csv")

# %%
file_sorted.iloc[0:9,:]
# Out:
#          "ID"           "SheetID"           "MedCardNo" "位置"         "腺体回声"  \
# 0  "13505023"  "2010111100100050"  "B00327070         "  "0"  "增多，增强，分布欠均匀"
# 1  "13505023"  "2010111100100050"  "B00327070         "  "1"  "增多，增强，分布欠均匀"
# 2  "13505688"  "2010111100100222"  "Q01640383         "  "0"             ""
# 3  "13505688"  "2010111100100222"  "Q01640383         "  "1"             ""
# 4  "13505693"  "2010111100100223"  "132002100307370   "  "0"             ""
# 5  "13505693"  "2010111100100223"  "132002100307370   "  "1"             ""
# 6  "13505698"  "2014012701300049"  "E12477019         "  "0"  "增多，增强，分布欠均匀"
# 7  "13505698"  "2014012701300049"  "E12477019         "  "1"  "增多，增强，分布欠均匀"
# 8  "17941386"  "2014042800520007"           "820127552"  "0"             ""
#
#   "腺体表面"      "腺管" "腺体形状" "乳腺组织厚度" "CFI"     ...     "低回声回声位置"  \
# 0  "尚光整"        ""     ""       ""    ""     ...            ""
# 1  "尚光整"        ""     ""       ""    ""     ...            ""
# ...

# %%
file_X = loadCSV("原_乳腺X光影像病理诊断.csv")
file_B = loadCSV("原_乳腺超声影像病理诊断.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ddcd93e5fb9f> in <module>()
# ----> 1 file_X = loadCSV("原_乳腺X光影像病理诊断.csv")
#       2 file_B = loadCSV("原_乳腺超声影像病理诊断.csv")
#
# NameError: name 'loadCSV' is not defined
